# %% [markdown]
# # Feature_transformation

# %% [markdown]
# # ML da feature_transformation bu - modelga beriladigan ustunlarni yaxshiroq taqsimotga keltirish, shkalalash va model samaradorligini oshirish jarayonidir

# %% [markdown]
# # Skewness - bu feature taqsimotini chap va o'ng tomonga og'ib ketganligini bildiradi

# %% [markdown]
# # Skewness - bu taqsimotning simmetrik emasligini o'lchaydi
# - Skewness = 0 bo'lsa bu normal taqsimot
# - Skewness > 0 bo'lsa bu o'nga qiyshiq taqsimot, bu pozitiv skewness
# - Skewness < 0 bo'lsa bu chapga qiyshiq taqsimot, bu negative skiwness deyiladi

# %% [markdown]
# # Positive Skiwnessni oldini olish uchun - LOG transformatsiya ishlatiladi
# # Negative Skewnessni oldini olish uchun - SQRT transformation ishlatiladi
#
# # Agarda manfiy bo'lsa barcha qiymatlarga c=constant qiymat qo'shiladi

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

df=sns.load_dataset("titanic")

num_cols = ["age", "fare", "sibsp", "parch"]

skewness = df[num_cols].skew()
print(skewness)
# Out:
# age      0.389108
# fare     4.787317
# sibsp    3.695352
# parch    2.749117
# dtype: float64

# %% [markdown]
# # Log Transformation - Katta skewnesslar uchun

# %%
import numpy as np 

df["fare_log"] = np.log1p(df["fare"])

# %% [markdown]
# # log1p - bu log(1 + x ) no`l qiymatlar uchun havfsiz

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
#  15  fare_log     891 non-null    float64
# dtypes: bool(2), category(2), float64(3), int64(4), str(5)
# memory usage: 87.6 KB

# %%
num_cols = ["fare_log"]
skewness = df[num_cols].skew()
print(skewness)
# Out:
# fare_log    0.394928
# dtype: float64

# %% [markdown]
# # Square Root Transformation - bu yengil skewnesslar uchun

# %%
df["fare_sqrt"] = np.sqrt(df["fare"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
#  15  fare_log     891 non-null    float64
#  16  fare_sqrt    891 non-null    float64
# dtypes: bool(2), category(2), float64(4), int64(4), str(5)
# memory usage: 94.6 KB

# %%
num_cols = ["fare_sqrt"]
skewness = df[num_cols].skew()
print(skewness)
# Out:
# fare_sqrt    2.085004
# dtype: float64

# %% [markdown]
# # Box - Cox Transformation - faqatgina musbat skewnesslar uchun

# %%
from scipy.stats import boxcox

fare_bc, lambda_ = boxcox(df["fare"].dropna)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 from scipy.stats import boxcox
# ----> 3 fare_bc, lambda_ = boxcox(df["fare"].dropna)
#
# File c:\Users\Jahongir\Desktop\Project_One\myvenv\Lib\site-packages\scipy\stats\_morestats.py:1198, in boxcox(x, lmbda, alpha, optimizer)
#    1195     return special.boxcox(x, lmbda)
#    1197 if x.ndim != 1:
# -> 1198     raise ValueError("Data must be 1-dimensional.")
#    1200 if x.size == 0:
#    1201     return x
#
# ValueError: Data must be 1-dimensional.

# %% [markdown]
# # Agarda biz bergan ustun ichida manfiy yoki 0 qiymatlar bo'lsa hatolik beradi!

# %% [markdown]
# # Yeo-Johnson Transformation - manfiy va 0 qiymatlar bilan ishlaydi

# %%
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer(method='yeo-johnson')
df[["fare_yj"]] = pt.fit_transform(df[["fare"]])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
#  15  fare_log     891 non-null    float64
#  16  fare_sqrt    891 non-null    float64
#  17  fare_yj      891 non-null    float64
# ...

# %%
num_cols = ["fare_yj"]
skewness = df[num_cols].skew()
print(skewness)
# Out:
# fare_yj   -0.040329
# dtype: float64

# %% [markdown]
# # Visual taqqoslash

# %%
fix, axes = plt.subplots(1,2,figsize=(12,4))

sns.histplot(df["fare"], kde=True, ax=axes[0])
axes[0].set_title("Original Fare Xolati")

sns.histplot(df["fare_log"], kde=True, ax=axes[1])
axes[1].set_title("Logdan keyingi holati")

plt.show()

# %% [markdown]
# # Transformation va scalingni biri biridan farqi shuki transformationda har bir ustun boyicha qiymatlarni taqsimotini normalga yaqinlashitradi scaling esa umumiy barecha featuirelarni bitta chegarali miqdorga keltiradi /// birinchi transform ishlatiladi so`ng scaling qilinadi
