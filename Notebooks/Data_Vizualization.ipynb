# %% [markdown]
# # DATA VIZUALIZATION

# %% [markdown]
# # 1-Basic / Fundamentail plotlar
# - Line plot
# - Multi-line plot
# - step plot
# - area plot
# - stacked area plot

# %% [markdown]
# # 2- Distribution plotlar (Taqsimot plotlari)
# - Histogram
# - KDE plot
# - Histogram + KDE
# - Rug Plot
# - ECDF plot
# - Frequence polygon
# - density plot
# - distplot (deprecated)

# %% [markdown]
# # 3 -  Categorical Plotlar
# - Bar plot
# - Horizontal plot
# - Grouped  bar plot
# - stacked bar plot
# - count plot
# - point plot
# - strip plot
# - swarm plot
# - lollipop plot
# - dot plot

# %% [markdown]
# # 4- Relationship plotlar (Correlation)
# - Scatter plot
# - Scatter plot (colored/sized)
# - Regression plot
# - joint plot
# - pair plot
# - Hexbin plot
# - bubble chart

# %% [markdown]
# # 5- Statistical plotlar
# - box plot
# - boxen plot
# - violin plot
# - error bar plot
# - confidence interval plot
# - mean plot
# - standart deviation plot

# %% [markdown]
# # 6 - Matrix / structure plotlar
# - Heatmap
# - Correation heatmap
# - clustermap
# - distance matrix plot

# %% [markdown]
# # 7- Multivariate / high- dimensional plotlar
# - Pairwise scatter matrix
# - parallel coordinates plot
# - andrews curves
# - radial plot
# - radar chart
# - star plot

# %% [markdown]
# # 8 - Time Series Plotlar
# - Time-series line plot
# - rolling mena plot
# - rolling std plot
# - lag plot
# - autocorrelation plot (ACF)
# - partial autocorrelation plot (PACF)
# - seasonal plot
# - decomposition  plot (trend/ seasonal/ residual)

# %% [markdown]
# # 9 - Ranking & comparision plotlar
# - rank plot
# - slope chart
# - dumbbell plot
# - waterfall plot
# - funnel chart

# %% [markdown]
# # 10 - Proportion / compositional plotlar
# - pie chart
# - donut chart
# - stacked bar
# - mosaic plot
# - waffle chart

# %% [markdown]
# # 11 - Hierarchical plotlar
# - treemap
# - sunburst chart
# - icicle chart
# - dendrogram

# %% [markdown]
# # 12 - Geographical plotlar
# - choropleth map
# - scatter geo map
# - bubble map
# - heatmap geo
# - line map
# - density map

# %% [markdown]
# # 13 - Interactive / dashboard plotlar
# - interactive line
# - interactive bar
# - interactive scatter
# - hover enabled heatmap
# - animated plot
# - sider - based plot

# %% [markdown]
# # 14 - ML / Data Science maxsus plotlar
# - Confusion matrix
# - ROC curve
# - presicion recall curve
# - lift curve
# - gain chart
# - feature importance plot
# - SHAP Summary plot
# - SHAP dependence plot
# - Partial dependence plot (PDP)

# %% [markdown]
# # 15 - Advanced  plotlar (kam ishlatiladi)
# - Hexagon  bin density plot
# - Streamgraph
# - horizon chart
# - ridgeline plot
# - sankey diagram
# - chord diagram
# - network graph
# - graph adjacency plot

# %% [markdown]
# # 16 - 3D Plotlar
# - 3D scatter
# - 3D surface
# - 3D wirframe
# - 3D contour

# %% [markdown]
# # Manashu 102 xil Plotlarning Kodli misollarini ko`rib chiqamiz

# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.6-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\jahongir\desktop\project_one\myvenv\lib\site-packages (from statsmodels) (2.4.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\jahongir\desktop\project_one\myvenv\lib\site-packages (from statsmodels) (1.17.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\jahongir\desktop\project_one\myvenv\lib\site-packages (from statsmodels) (3.0.1)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\jahongir\desktop\project_one\myvenv\lib\site-packages (from statsmodels) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jahongir\desktop\project_one\myvenv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\jahongir\desktop\project_one\myvenv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\jahongir\desktop\project_one\myvenv\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.6-cp313-cp313-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.5 MB 360.6 kB/s eta 0:00:26
#    -- ------------------------------------- 0.5/9.5 MB 360.6 kB/s eta 0:00:26
#    --- ------------------------------------ 0.8/9.5 MB 464.6 kB/s eta 0:00:19
#    ---- ----------------------------------- 1.0/9.5 MB 546.6 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.0/9.5 MB 546.6 kB/s eta 0:00:16
#    ----- ---------------------------------- 1.3/9.5 MB 611.5 kB/s eta 0:00:14
#    ------ --------------------------------- 1.6/9.5 MB 660.9 kB/s eta 0:00:13
#    ------- -------------------------------- 1.8/9.5 MB 703.4 kB/s eta 0:00:11
#    -------- ------------------------------- 2.1/9.5 MB 729.1 kB/s eta 0:00:11
#    --------- ------------------------------ 2.4/9.5 MB 763.5 kB/s eta 0:00:10
#    --------- ------------------------------ 2.4/9.5 MB 763.5 kB/s eta 0:00:10
#    --------- ------------------------------ 2.4/9.5 MB 763.5 kB/s eta 0:00:10
#    ---------- ----------------------------- 2.6/9.5 MB 701.6 kB/s eta 0:00:10
#    ---------- ----------------------------- 2.6/9.5 MB 701.6 kB/s eta 0:00:10
#    ---------- ----------------------------- 2.6/9.5 MB 701.6 kB/s eta 0:00:10
#    ---------- ----------------------------- 2.6/9.5 MB 701.6 kB/s eta 0:00:10
#    ---------- ----------------------------- 2.6/9.5 MB 701.6 kB/s eta 0:00:10
#    ------------ --------------------------- 2.9/9.5 MB 603.2 kB/s eta 0:00:12
#    ------------ --------------------------- 2.9/9.5 MB 603.2 kB/s eta 0:00:12
#    ------------- -------------------------- 3.1/9.5 MB 596.5 kB/s eta 0:00:11
#    ------------- -------------------------- 3.1/9.5 MB 596.5 kB/s eta 0:00:11
#    -------------- ------------------------- 3.4/9.5 MB 623.2 kB/s eta 0:00:10
#    --------------- ------------------------ 3.7/9.5 MB 641.0 kB/s eta 0:00:10
#    ---------------- ----------------------- 3.9/9.5 MB 666.3 kB/s eta 0:00:09
#    ----------------- ---------------------- 4.2/9.5 MB 672.1 kB/s eta 0:00:08
#    ------------------ --------------------- 4.5/9.5 MB 696.8 kB/s eta 0:00:08
#    ------------------- -------------------- 4.7/9.5 MB 713.8 kB/s eta 0:00:07
#    -------------------- ------------------- 5.0/9.5 MB 740.6 kB/s eta 0:00:07
#    ----------------------- ---------------- 5.5/9.5 MB 784.8 kB/s eta 0:00:06
#    ------------------------ --------------- 5.8/9.5 MB 805.3 kB/s eta 0:00:05
#    ------------------------- -------------- 6.0/9.5 MB 824.1 kB/s eta 0:00:05
#    --------------------------- ------------ 6.6/9.5 MB 865.5 kB/s eta 0:00:04
#    ----------------------------- ---------- 7.1/9.5 MB 908.2 kB/s eta 0:00:03
#    ------------------------------- -------- 7.6/9.5 MB 950.1 kB/s eta 0:00:03
#    -------------------------------- ------- 7.9/9.5 MB 964.4 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.4/9.5 MB 994.7 kB/s eta 0:00:02
#    ------------------------------------ --- 8.7/9.5 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.5 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 1.1 MB/s eta 0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.2 statsmodels-0.14.6
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from pandas.plotting import(
    scatter_matrix, parallel_coordinates, andrews_curves, lag_plot
)

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (6,4)

# %% [markdown]
# # Real datasetlarni chaqirib olish

# %%
titanic = sns.load_dataset("titanic")
iris = sns.load_dataset("iris")
tips =sns.load_dataset("tips")
flights = sns.load_dataset("flights")

# %% [markdown]
# # BASIC PLOTLAR

# %%
plt.plot(flights["year"], flights["passengers"])
plt.show()

# %%
plt.step(flights["year"], flights["passengers"])
plt.show()

# %%
plt.fill_between(flights["year"], flights["passengers"])
plt.show()

# %%
plt.hist(titanic["age"].dropna(),bins=30)
plt.show()
