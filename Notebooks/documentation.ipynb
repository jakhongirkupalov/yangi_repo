# %% [markdown]
# # Fayl ReadMe.md si haqida

# %% [markdown]
# # md fayl bu MARKDOWN formati bo'lib bu asosan strukturali matnlar, oson o'qilishi kerak bolgan formatlar jamlanmasi

# %% [markdown]
# # md formati asosan qayerlarda ishlatiladi
# - documentatsiyada
# - blokpostlarda
# - ReadMe yozganda
# - boshqa matnli hujjatlarni yozishda

# %% [markdown]
# # Formatlash belgilari
#
# # bitta # bo'lsa birinchi darajali sarlavha
# # ikkita ## bolsa 2-darajali sarlavha hisoblanadi
#
#
# # Sarlavha - 1
#
# ## sarlavha - 2

# %% [markdown]
# # ** bo'lsa bu qalin matn BOLD

# %% [markdown]
# # **SALOMLAR**

# %% [markdown]
# # - YOKI * QO'YISH KETMAKETLIKNI BILDIRADI

# %% [markdown]
# - bir
# - ikki
# - uch
# - to'rt
# - besh
# - olti

# %% [markdown]
# # `print()` - bu belgi kod yoki kamandalarni belgilash

# %% [markdown]
# `print("Hello world")`

# %% [markdown]
# # ![alt text](link) - bu rasm qo'yish joyi

# %% [markdown]
# ![Logo](https://www.adobe.com/express/feature/image/remove-background/png/transparent)

# %% [markdown]
# # Loyihaning ReadME.md fayli quyidagi qismlardan tashkil topgan bo'lishi kerak
#
# - Loyiha nomi va qisqacha tarifi
#
# # 1) Project Name
# Qisqacha loyiha haqida izoh. Masalan: "Bu loyiha ML modelni avtomotik o'rgatish uchun yaratilgan."
#
# # 2) Status / Badge (Ixtiyoriy)
# - Build status, test coverage, license kabi "badges" qo'yish mumkin:
# - ![Build](https://img.shields.io/badge/build-passing-brightgreen)
#
# # 2-a) Technical Contribution -- Texnik jixatdan xulosa
#
# - qaysi algoritmlar tanlandi
# - qanaqa feature engineering bo'ldi
# - muammolar va yechimlar
# - oldingi va keyingi natijalar
# - oldingi va keyingi yaxshilangan natijani aniq berib ketish kerak
# -- MISOL UCHUN Basilen da natijam Accuracy score 0.75 % edi keyin ensemble modeldan so'ng natija 0.87% ga oshdi
#
# # 2-b) Business Contribution -- Bizness jixatdan xulosa
# - Foydalanuvchi  yoki kompaniya qanday qiymat olishi mumkin
# - foyda, vaqt, muammo yechimi tarafdan afzal tomonlari
# - real natijalar bilan buni yozib ketish
# - berishingiz mumkin bo'lgan foymadi yozib keting
# # 3) Qanday o'rnatish / Installation
#
# # Installation
# 1. Repo'ni klonlash: `git clone https://github.com/user/project.git`
# 2. Kerakli paketlarni o'rnatish:`pip install -r requeriments.txt`
#
# # 4) Qanday Ishlatish haqida
#
#
# ## usage
# bash
# python main.py
#
# from project import module
# module.run()
#
#
# # 5) Funksiyalar yoki imkoniyatlar haqida
#
# ## Features
#  - Feature 1
#  - Feature 2
#  - Feature 3
#
# # 6) Litsenziya
# MIT License © 2026
#
# # 7) Aloqa
#
# ## Contact
# - Email: example@gmail.com
# - Github: [username](https://github.com/username)

# %% [markdown]
# # Emojilarni ReadMe.md faylga qo`shish
#
# - 🚀 Installation
# - 🔧 Features
# - ✅ Completed tasks
#
# ## 🚀 Technical Contribution
# - 🧪 Performed EDA using Pandas & Seaborn
# - 🔧 Applied ML models: Logistic Regression, Random Forest
# - ⚡ Optimized performance with hyperparameter tuning
#
# Emoji yaratish tartibi quyidagicha
# :rocket: O`rnatish

# %% [markdown]
# ✅ O`rnatish
# :gear: nastroyka
# :chart_with_upwards_trends:

# %%
# SAYT emojipedia.org
