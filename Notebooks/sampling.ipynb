# %% [markdown]
# # Imbalance Datasetlarda Sampling

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Jahongir\Desktop\Project_One\Data\Raw_Data\titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df["Survived"].unique()
# Out:
# array([0, 1])

# %%
df["Survived"].nunique()
# Out:
# 2

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Target ustunida chiqayotgan natijada har bitta class bo'yicha sonlar teng bo'lmasa bu IMBALANCE Dataset deyiladi, yani (MUVOZANATSIZ MA'LUMOTLAR TO'PLAMI)

# %% [markdown]
# # Target ustunidagi qiymati kam bolgan classni MINORITY deb nomlaymiz
# # Qiymat jihatidan kop bolgan classni MAJORITY deb nomlaymiz

# %% [markdown]
# # Agarda IMBALANCE data set bilan model training qilinsa quyidaagicha xatoliklar sodir bo;ladi:
# - kichik miqdordagi classlarni ignore qiladi
# - kichik miqdordagi classlar ustida past natija chiqadi
# - umumiy natija baland bo'lishi mumkin, lekin biazed performens bo'ladi  va bu Overfittingga sabab bo'ladi

# %% [markdown]
# # Yechimi

# %% [markdown]
# # 1- yechim bu minority classni oshirish == OVERSAMPLING
# # 2-yechim bu majority classni kamaytirish == UNDERSAMPLING

# %% [markdown]
# # Sampling texnikalari (OVERSAMPLING VA UNDERSAMPLING) - bu texnikalar classification tasklarda model generalization va fairnessni oshiradi

# %% [markdown]
# # GENERALIZATION - Bu modelni umumiylik yoki umumlashtirish qobilyati
# # Fairness - Bu modelning biror tarafga yon bosmay adolatli qaror qabul qilishi

# %% [markdown]
# # OVERSAMPLING

# %%
# OVERSAMPLINGDA - kichik miqdordagi classlardagi qiymatlarni oshirish va katta miqdordagi classlar soniga yetkazishga aytiladi

# %% [markdown]
# # MultiClass bolsa u xolda eng kop class soniga qarab yetkaziladi va yani 1 dan 3 ta 0 dan 2ta 2dan 8 ta bolsa 0 va 1 ni 8taga yetkazamiz

# %% [markdown]
# # OVERSAMPLING Texnikalari
#
# - Random Oversampling
# - SMOTE
# - ADASYN

# %% [markdown]
# # Random Oversampling

# %% [markdown]
# # bunda ishlash prinsipi shundaki qiymatlarni dubliket qilish orqali kopaytirib qo'yadi, tanlab olganda randomli holatda tanlaydi

# %% [markdown]
# # SMOTE

# %% [markdown]
# # buni ishlash prinspi shundaki - (sythetic minoraty oversampling technique)- suniy qiymatlarni yaratish orqali qiymatlar qo'shadi

# %% [markdown]
# #           SAMPLING AMALIYOT

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset("titanic")

df = df[["survived", "pclass", "sex", "age", "fare"]]
df["age"].fillna(df["age"].median(), inplace=True)
df["sex"] = df["sex"].map({"male":0, "female":1})

x = df.drop("survived", axis=1)
y = df["survived"]

print(y.value_counts())
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64
# C:\Users\Jahongir\AppData\Local\Temp\ipykernel_7096\1419930161.py:7: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["age"].fillna(df["age"].median(), inplace=True)

# %%
print(y.value_counts())
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Random Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)

x_ros, y_ros = ros.fit_resample(x,y)

print(y_ros.value_counts())
# Out:
# survived
# 0    549
# 1    549
# Name: count, dtype: int64

# %% [markdown]
# # SMOTE

# %%
x = x.fillna(x.median())

from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42, k_neighbors=5)

x_smote, y_smote = smote.fit_resample(x,y)

print(y_smote.value_counts())
# Out:
# survived
# 0    549
# 1    549
# Name: count, dtype: int64

# %% [markdown]
# # ADASYN

# %%
from imblearn.over_sampling import ADASYN

adasyn = ADASYN(random_state=42)

x_adasyn, y_adasyn = adasyn.fit_resample(x,y)

print(y_adasyn.value_counts())
# Out:
# survived
# 1    571
# 0    549
# Name: count, dtype: int64

# %% [markdown]
# # Random UnderSampling

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)

x_rus, y_rus= rus.fit_resample(x,y)

print(y_rus.value_counts())
# Out:
# survived
# 0    342
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Cluster Centroids

# %%
from imblearn.under_sampling import ClusterCentroids

cc = ClusterCentroids(random_state=42)

x_cc, y_cc= rus.fit_resample(x,y)

print(y_cc.value_counts())
# Out:
# survived
# 0    342
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Near Miss

# %%
from imblearn.under_sampling import NearMiss

nearmiss = NearMiss(version=1)

x_nearmiss, y_nearmiss= rus.fit_resample(x,y)

print(y_nearmiss.value_counts())
# Out:
# survived
# 0    342
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# | Holat               | Tavsiya             |
# |---------------------|---------------------|
# | Dataset kichik      | SMOTE               |
# | Juda katta dataset  | Undersampling       |
# | Shovqin kam         | ADASYN              |
# | Tez baseline        | RandomOverSampler   |
# | Klasslar yaqin      | NearMiss            |
# | Katta majority      | ClusterCentroids    |
