# %% [markdown]
# # Virtual Environment nima - bu python loyihasi uchun alohida, izolyatsiyalangan muhit

# %% [markdown]
# # Har bir loyiha o'zining python paketlariga ozining versiyalariga alohida kodlariga ega bo'ladi

# %% [markdown]
# # Misol uchun
# 1) Project-1 == Numpy == 1.26.3
# 2) Project-2 == Numpy == 2.0
#
# Agarda biz bularni global pythonda ishlatsak birinchisi ikkinchisini buzadi

# %% [markdown]
# # Venvni ichidagi papkalar vazifasi
#
# 1. include - umumiy maxsulotlar joylashgan
# 2. lib - barcha python packagelar
# 3. Scripts - umumiy boshqaruv fayllari
# 4. pyvenv.cfg -- bu faylda ichki konstitutsiya yozilgaan bo'ladi

# %% [markdown]
# # Zaruriy Kutubxonalar
#
# 1) pandas
# 2) numpy
# 3) openpyxl
# 4) matplotlib
# 5) seaborn
# 6) plotly
# 7) scikit-learn
# 8) xgboost
# 9) lightbgm
# 10) catboost
